# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open('../datasets/photo.jpeg')

# %%
image = np.array(image)

# %%
image.shape
# Out:
# (1034, 748, 3)

# %%
image[0, 0]
# Out:
# array([45, 29, 30], dtype=uint8)

# %%
plt.imshow(image) # show image from array

# %%
plt.imshow(image[:image.shape[0]//2])

# %%
im = image.copy()
im[:, 300:310, :] = [0, 0, 0]
plt.imshow(im[:, :im.shape[1]//2, :])

# %%
im2 = image.copy()
im2[:, :, 0] = 255
plt.imshow(im2[:, :im2.shape[1]//2, :])

# %%
plt.imshow(image) # show image from array

# %%
photo = image.copy()
photo[300:700, 400:410] = [255, 0, 0]
photo[300:700, 600:610] = [255, 0, 0]
photo[300:310, 400:610] = [255, 0, 0]
photo[700:710, 400:610] = [255, 0, 0]


plt.imshow(photo)
